# %% [markdown]
# <a href="https://colab.research.google.com/github/juliana-zh/accessibility_quiz/blob/main/to_pandas_calculate_average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.0 MB/s eta 0:00:00
# ...

# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip"
# !unzip drugsCom_raw.zip
# Out:
# --2023-09-05 12:04:46--  https://archive.ics.uci.edu/ml/machine-learning-databases/00462/drugsCom_raw.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘drugsCom_raw.zip’
#
# drugsCom_raw.zip        [       <=>          ]  41.00M  31.3MB/s    in 1.3s
#
# 2023-09-05 12:04:48 (31.3 MB/s) - ‘drugsCom_raw.zip’ saved [42989872]
#
# Archive:  drugsCom_raw.zip
#   inflating: drugsComTest_raw.tsv
#   inflating: drugsComTrain_raw.tsv

# %%
from datasets import load_dataset

data_files = {"train": "drugsComTrain_raw.tsv", "test": "drugsComTest_raw.tsv"}
# \t is the tab character in Python
drug_dataset = load_dataset("csv", data_files=data_files, delimiter="\t")
# Out:
# ...
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
drug_sample = drug_dataset["train"].shuffle(seed=42).select(range(1000))

# %%
df = drug_sample.to_pandas()
df.head()
# Out:
#    Unnamed: 0    drugName                condition  \
# 0       87571    Naproxen              Gout, Acute
# 1      178045  Duloxetine              ibromyalgia
# 2       80482       Mobic  Inflammatory Conditions
# 3      159268    TriNessa            Birth Control
# 4      205477     Pristiq               Depression
#
#                                               review  rating  \
# 0  "like the previous person mention, I&#039;m a ...     9.0
# 1  "I have taken Cymbalta for about a year and a ...     3.0
# 2  "I have been taking Mobic for over a year with...    10.0
# 3  "I am now 21 and have been on TriNessa since I...    10.0
# 4  "I was originally on Prozac 20mg for my depres...    10.0
#
#                 date  usefulCount
# 0  September 2, 2015           36
# 1   November 7, 2011           13
# 2       June 5, 2013          128
# 3   October 21, 2010           81
# 4      July 13, 2013           65

# %%
df.groupby('rating').mean()
# Out:
# <ipython-input-17-82c1a078b0f0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('rating').mean()
#            Unnamed: 0  usefulCount
# rating
# 1.0     103566.812500    14.965278
# 2.0     144204.018519    20.666667
# 3.0     135605.416667    18.000000
# 4.0     108782.758621    18.724138
# 5.0     118554.944444    25.944444
# 6.0     122482.117647    21.294118
# 7.0     114851.056604    26.433962
# 8.0     116530.885965    26.692982
# 9.0     115464.212121    36.157576
# 10.0    112092.424749    37.431438

# %%
drug_sample.reset_format()

# %%
u = None

# %%
# %timeit u is None
# Out:
# 49.8 ns ± 16.5 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
